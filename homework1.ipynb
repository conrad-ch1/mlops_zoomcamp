# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
# Load the dataset - January 2023
df = pd.read_parquet("data/yellow_tripdata_2023-01.parquet")
df
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               2  2023-01-01 00:32:10   2023-01-01 00:40:36              1.0
# 1               2  2023-01-01 00:55:08   2023-01-01 01:01:27              1.0
# 2               2  2023-01-01 00:25:04   2023-01-01 00:37:49              1.0
# 3               1  2023-01-01 00:03:48   2023-01-01 00:13:25              0.0
# 4               2  2023-01-01 00:10:29   2023-01-01 00:21:19              1.0
# ...           ...                  ...                   ...              ...
# 3066761         2  2023-01-31 23:58:34   2023-02-01 00:12:33              NaN
# 3066762         2  2023-01-31 23:31:09   2023-01-31 23:50:36              NaN
# 3066763         2  2023-01-31 23:01:05   2023-01-31 23:25:36              NaN
# 3066764         2  2023-01-31 23:40:00   2023-01-31 23:53:00              NaN
# 3066765         2  2023-01-31 23:07:32   2023-01-31 23:21:56              NaN
#
#          trip_distance  RatecodeID store_and_fwd_flag  PULocationID  \
# 0                 0.97         1.0                  N           161
# 1                 1.10         1.0                  N            43
# 2                 2.51         1.0                  N            48
# 3                 1.90         1.0                  N           138
# 4                 1.43         1.0                  N           107
# ...                ...         ...                ...           ...
# 3066761           3.05         NaN               None           107
# 3066762           5.80         NaN               None           112
# 3066763           4.67         NaN               None           114
# 3066764           3.15         NaN               None           230
# 3066765           2.85         NaN               None           262
#
#          DOLocationID  payment_type  fare_amount  extra  mta_tax  tip_amount  \
# 0                 141             2         9.30   1.00      0.5        0.00
# 1                 237             1         7.90   1.00      0.5        4.00
# 2                 238             1        14.90   1.00      0.5       15.00
# 3                   7             1        12.10   7.25      0.5        0.00
# 4                  79             1        11.40   1.00      0.5        3.28
# ...               ...           ...          ...    ...      ...         ...
# 3066761            48             0        15.80   0.00      0.5        3.96
# 3066762            75             0        22.43   0.00      0.5        2.64
# 3066763           239             0        17.61   0.00      0.5        5.32
# 3066764            79             0        18.15   0.00      0.5        4.43
# 3066765           143             0        15.97   0.00      0.5        2.00
#
#          tolls_amount  improvement_surcharge  total_amount  \
# 0                 0.0                    1.0         14.30
# 1                 0.0                    1.0         16.90
# 2                 0.0                    1.0         34.90
# 3                 0.0                    1.0         20.85
# 4                 0.0                    1.0         19.68
# ...               ...                    ...           ...
# 3066761           0.0                    1.0         23.76
# 3066762           0.0                    1.0         29.07
# 3066763           0.0                    1.0         26.93
# 3066764           0.0                    1.0         26.58
# 3066765           0.0                    1.0         21.97
#
#          congestion_surcharge  airport_fee
# 0                         2.5         0.00
# 1                         2.5         0.00
# 2                         2.5         0.00
# 3                         0.0         1.25
# 4                         2.5         0.00
# ...                       ...          ...
# 3066761                   NaN          NaN
# 3066762                   NaN          NaN
# 3066763                   NaN          NaN
# 3066764                   NaN          NaN
# 3066765                   NaN          NaN
#
# [3066766 rows x 19 columns]

# %%
len(df.columns)
# Out:
# 19

# %%
df["duration"] = (df["tpep_dropoff_datetime"] - df["tpep_pickup_datetime"])

# %%
df["duration"] = df["duration"].apply(lambda x: x.total_seconds() / 60)
df["duration"]
# Out:
# 0           8.433333
# 1           6.316667
# 2          12.750000
# 3           9.616667
# 4          10.833333
#              ...
# 3066761    13.983333
# 3066762    19.450000
# 3066763    24.516667
# 3066764    13.000000
# 3066765    14.400000
# Name: duration, Length: 3066766, dtype: float64

# %%
min(df["duration"])
# Out:
# -29.2

# %%
max(df["duration"])
# Out:
# 10029.183333333332

# %%
np.mean(df["duration"])
# Out:
# np.float64(15.668995167330452)

# %%
np.std(df["duration"])
# Out:
# np.float64(42.59434429744777)

# %%
original_len = len(df)
original_len
# Out:
# 3066766

# %%
df = df.query("duration >= 1 & duration <= 60")
df = df.reset_index()

# %%
updated_len = len(df)
updated_len
# Out:
# 3009173

# %%
(updated_len / original_len) * 100
# Out:
# 98.1220282212598

# %%
df
# Out:
#            index  VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# 0              0         2  2023-01-01 00:32:10   2023-01-01 00:40:36
# 1              1         2  2023-01-01 00:55:08   2023-01-01 01:01:27
# 2              2         2  2023-01-01 00:25:04   2023-01-01 00:37:49
# 3              3         1  2023-01-01 00:03:48   2023-01-01 00:13:25
# 4              4         2  2023-01-01 00:10:29   2023-01-01 00:21:19
# ...          ...       ...                  ...                   ...
# 3009168  3066761         2  2023-01-31 23:58:34   2023-02-01 00:12:33
# 3009169  3066762         2  2023-01-31 23:31:09   2023-01-31 23:50:36
# 3009170  3066763         2  2023-01-31 23:01:05   2023-01-31 23:25:36
# 3009171  3066764         2  2023-01-31 23:40:00   2023-01-31 23:53:00
# 3009172  3066765         2  2023-01-31 23:07:32   2023-01-31 23:21:56
#
#          passenger_count  trip_distance  RatecodeID store_and_fwd_flag  \
# 0                    1.0           0.97         1.0                  N
# 1                    1.0           1.10         1.0                  N
# 2                    1.0           2.51         1.0                  N
# 3                    0.0           1.90         1.0                  N
# 4                    1.0           1.43         1.0                  N
# ...                  ...            ...         ...                ...
# 3009168              NaN           3.05         NaN               None
# 3009169              NaN           5.80         NaN               None
# 3009170              NaN           4.67         NaN               None
# 3009171              NaN           3.15         NaN               None
# 3009172              NaN           2.85         NaN               None
#
#          PULocationID  DOLocationID  ...  fare_amount  extra  mta_tax  \
# 0                 161           141  ...         9.30   1.00      0.5
# 1                  43           237  ...         7.90   1.00      0.5
# 2                  48           238  ...        14.90   1.00      0.5
# 3                 138             7  ...        12.10   7.25      0.5
# 4                 107            79  ...        11.40   1.00      0.5
# ...               ...           ...  ...          ...    ...      ...
# 3009168           107            48  ...        15.80   0.00      0.5
# 3009169           112            75  ...        22.43   0.00      0.5
# 3009170           114           239  ...        17.61   0.00      0.5
# 3009171           230            79  ...        18.15   0.00      0.5
# 3009172           262           143  ...        15.97   0.00      0.5
#
#          tip_amount  tolls_amount  improvement_surcharge  total_amount  \
# 0              0.00           0.0                    1.0         14.30
# 1              4.00           0.0                    1.0         16.90
# 2             15.00           0.0                    1.0         34.90
# 3              0.00           0.0                    1.0         20.85
# 4              3.28           0.0                    1.0         19.68
# ...             ...           ...                    ...           ...
# 3009168        3.96           0.0                    1.0         23.76
# 3009169        2.64           0.0                    1.0         29.07
# 3009170        5.32           0.0                    1.0         26.93
# 3009171        4.43           0.0                    1.0         26.58
# 3009172        2.00           0.0                    1.0         21.97
#
#          congestion_surcharge  airport_fee   duration
# 0                         2.5         0.00   8.433333
# 1                         2.5         0.00   6.316667
# 2                         2.5         0.00  12.750000
# 3                         0.0         1.25   9.616667
# 4                         2.5         0.00  10.833333
# ...                       ...          ...        ...
# 3009168                   NaN          NaN  13.983333
# 3009169                   NaN          NaN  19.450000
# 3009170                   NaN          NaN  24.516667
# 3009171                   NaN          NaN  13.000000
# 3009172                   NaN          NaN  14.400000
#
# [3009173 rows x 21 columns]

# %%
df = df.reindex(columns=["PULocationID", "DOLocationID", "duration"])

# %%
df
# Out:
#          PULocationID  DOLocationID   duration
# 0                 161           141   8.433333
# 1                  43           237   6.316667
# 2                  48           238  12.750000
# 3                 138             7   9.616667
# 4                 107            79  10.833333
# ...               ...           ...        ...
# 3009168           107            48  13.983333
# 3009169           112            75  19.450000
# 3009170           114           239  24.516667
# 3009171           230            79  13.000000
# 3009172           262           143  14.400000
#
# [3009173 rows x 3 columns]
